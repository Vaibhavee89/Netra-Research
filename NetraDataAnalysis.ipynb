# %%
  from google.colab import drive
  drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df1 = pd.read_csv("train.csv")
df2 = pd.read_csv("test.csv")

# %%
print(df1.head())
# Out:
#                                 category                       sub_category  \
# 0  Online and Social Media Related Crime  Cyber Bullying  Stalking  Sexting
# 1                 Online Financial Fraud                  Fraud CallVishing
# 2               Online Gambling  Betting           Online Gambling  Betting
# 3  Online and Social Media Related Crime                   Online Job Fraud
# 4                 Online Financial Fraud                  Fraud CallVishing
#
#                                   crimeaditionalinfo
# 0  I had continue received random calls and abusi...
# 1  The above fraudster is continuously messaging ...
# 2  He is acting like a police and demanding for m...
# 3  In apna Job I have applied for job interview f...
# 4  I received a call from lady stating that she w...

# %%
print(df2.head())
# Out:
#                                     category  \
# 0  RapeGang Rape RGRSexually Abusive Content
# 1                     Online Financial Fraud
# 2             Cyber Attack/ Dependent Crimes
# 3                     Online Financial Fraud
# 4                      Any Other Cyber Crime
#
#                            sub_category  \
# 0                                   NaN
# 1  DebitCredit Card FraudSim Swap Fraud
# 2                         SQL Injection
# 3                     Fraud CallVishing
# 4                                 Other
#
#                                   crimeaditionalinfo
# 0  Sir namaskar  mein Ranjit Kumar PatraPaise neh...
# 1          KOTAK MAHINDRA BANK FRAUD\r\nFRAUD AMOUNT
# 2  The issue actually started when I got this ema...
# 3  I am amit kumar from karwi chitrakoot I am tot...
# 4  I have ordered  saree and  blouse from rinki s...

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93686 entries, 0 to 93685
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   category            93686 non-null  object
#  1   sub_category        87095 non-null  object
#  2   crimeaditionalinfo  93665 non-null  object
# dtypes: object(3)
# memory usage: 2.1+ MB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31229 entries, 0 to 31228
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   category            31229 non-null  object
#  1   sub_category        28993 non-null  object
#  2   crimeaditionalinfo  31222 non-null  object
# dtypes: object(3)
# memory usage: 732.1+ KB
# None

# %%
merged_df = pd.concat([df1, df2], ignore_index=True)

# %%
merged_df.to_csv("cybercrime.csv", index=False)

# %%
df = pd.read_csv("cybercrime.csv")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124915 entries, 0 to 124914
# Data columns (total 3 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   category            124915 non-null  object
#  1   sub_category        116088 non-null  object
#  2   crimeaditionalinfo  124887 non-null  object
# dtypes: object(3)
# memory usage: 2.9+ MB
# None

# %%
print(df.shape)
# Out:
# (124915, 3)

# %%
print(df1.shape)
# Out:
# (93686, 3)

# %%
print(df2.shape)
# Out:
# (31229, 3)

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of                                      category  \
# 0       Online and Social Media Related Crime
# 1                      Online Financial Fraud
# 2                    Online Gambling  Betting
# 3       Online and Social Media Related Crime
# 4                      Online Financial Fraud
# ...                                       ...
# 124910  Online and Social Media Related Crime
# 124911                 Online Financial Fraud
# 124912                  Any Other Cyber Crime
# 124913                 Online Financial Fraud
# 124914                  Any Other Cyber Crime
#
#                              sub_category  \
# 0       Cyber Bullying  Stalking  Sexting
# 1                       Fraud CallVishing
# 2                Online Gambling  Betting
# 3                        Online Job Fraud
# 4                       Fraud CallVishing
# ...                                   ...
# 124910           Online Matrimonial Fraud
# ...

# %%
print(df.isnull().sum())
# Out:
# category                 0
# sub_category          8827
# crimeaditionalinfo      28
# dtype: int64

# %%
print(df['category'].unique())
# Out:
# ['Online and Social Media Related Crime' 'Online Financial Fraud'
#  'Online Gambling  Betting' 'RapeGang Rape RGRSexually Abusive Content'
#  'Any Other Cyber Crime' 'Cyber Attack/ Dependent Crimes'
#  'Cryptocurrency Crime' 'Sexually Explicit Act'
#  'Sexually Obscene material'
#  'Hacking  Damage to computercomputer system etc' 'Cyber Terrorism'
#  'Child Pornography CPChild Sexual Abuse Material CSAM'
#  'Online Cyber Trafficking' 'Ransomware' 'Report Unlawful Content'
#  'Crime Against Women & Children']

# %%
print(df['sub_category'].unique())
# Out:
# ['Cyber Bullying  Stalking  Sexting' 'Fraud CallVishing'
#  'Online Gambling  Betting' 'Online Job Fraud' 'UPI Related Frauds'
#  'Internet Banking Related Fraud' nan 'Other'
#  'Profile Hacking Identity Theft' 'DebitCredit Card FraudSim Swap Fraud'
#  'EWallet Related Fraud' 'Data Breach/Theft' 'Cheating by Impersonation'
#  'Denial of Service (DoS)/Distributed Denial of Service (DDOS) attacks'
#  'FakeImpersonating Profile' 'Cryptocurrency Fraud' 'Malware Attack'
#  'Business Email CompromiseEmail Takeover' 'Email Hacking'
#  'Hacking/Defacement' 'Unauthorised AccessData Breach' 'SQL Injection'
#  'Provocative Speech for unlawful acts' 'Ransomware Attack'
#  'Cyber Terrorism' 'Tampering with computer source documents'
#  'DematDepository Fraud' 'Online Trafficking' 'Online Matrimonial Fraud'
#  'Website DefacementHacking' 'Damage to computer computer systems etc'
#  'Impersonating Email' 'EMail Phishing' 'Ransomware' 'Intimidating Email'
# ...

# %%
print(df.isnull)
# Out:
# <bound method DataFrame.isnull of                                      category  \
# 0       Online and Social Media Related Crime
# 1                      Online Financial Fraud
# 2                    Online Gambling  Betting
# 3       Online and Social Media Related Crime
# 4                      Online Financial Fraud
# ...                                       ...
# 124910  Online and Social Media Related Crime
# 124911                 Online Financial Fraud
# 124912                  Any Other Cyber Crime
# 124913                 Online Financial Fraud
# 124914                  Any Other Cyber Crime
#
#                              sub_category  \
# 0       Cyber Bullying  Stalking  Sexting
# 1                       Fraud CallVishing
# 2                Online Gambling  Betting
# 3                        Online Job Fraud
# 4                       Fraud CallVishing
# ...                                   ...
# 124910           Online Matrimonial Fraud
# ...

# %%
empty_rows = df[df['crimeaditionalinfo'].isna()]

# %%
print(empty_rows)
# Out:
#                                      category  \
# 704                    Online Financial Fraud
# 803                     Any Other Cyber Crime
# 4105                   Online Financial Fraud
# 5789                   Online Financial Fraud
# 10513                  Online Financial Fraud
# 24040                  Online Financial Fraud
# 34999                  Online Financial Fraud
# 35538   Online and Social Media Related Crime
# 47593                  Online Financial Fraud
# 53571                  Online Financial Fraud
# 59690                  Online Financial Fraud
# 60063                  Online Financial Fraud
# 61196                  Online Financial Fraud
# 63767                  Online Financial Fraud
# 72420                  Online Financial Fraud
# 73574                  Online Financial Fraud
# 77589                  Online Financial Fraud
# 78744                  Online Financial Fraud
# 81490                  Online Financial Fraud
# ...

# %%
df_cleaned = df.dropna(subset=['crimeaditionalinfo'])

# %%
df_cleaned.to_csv("cleaned_dataset.csv", index=False)

# %%
empty_rows = df_cleaned[df_cleaned['crimeaditionalinfo'].isna()]

# %%
print(empty_rows)
# Out:
# Empty DataFrame
# Columns: [category, sub_category, crimeaditionalinfo]
# Index: []

# %%
import matplotlib.pyplot as plt

df_cleaned['category'].value_counts().plot(kind='bar')
plt.xlabel("Category")
plt.ylabel("Count")
plt.title("Category Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

df_cleaned['sub_category'].value_counts().plot(kind='bar')
plt.xlabel("Sub Category")
plt.ylabel("Count")
plt.title("Category Distribution")
plt.show()
